# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
df_sub = pd.read_csv('sample_submission.csv')

# %%
X_train = df_train['text']
y_train = df_train['target']
X_test = df_test['text']

# %%
from keras import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import pad_sequences
from keras.layers import Dense, LSTM, Embedding

# %%
token = Tokenizer()

# %%
token.fit_on_texts(X_train)

# %%
token.word_index
# Out:
# {'t': 1,
#  'co': 2,
#  'http': 3,
#  'the': 4,
#  'a': 5,
#  'in': 6,
#  'to': 7,
#  'of': 8,
#  'and': 9,
#  'i': 10,
#  'is': 11,
#  'for': 12,
#  'on': 13,
#  'you': 14,
#  'my': 15,
#  'with': 16,
#  'that': 17,
#  'it': 18,
#  'at': 19,
#  'by': 20,
#  'this': 21,
#  'from': 22,
#  'https': 23,
#  'are': 24,
#  'be': 25,
#  'was': 26,
#  'have': 27,
#  'like': 28,
#  'amp': 29,
#  'as': 30,
#  'up': 31,
#  'me': 32,
#  'but': 33,
#  'just': 34,
#  'so': 35,
#  'not': 36,
#  'your': 37,
#  'out': 38,
#  'no': 39,
#  'all': 40,
#  'after': 41,
#  'will': 42,
#  'an': 43,
#  'has': 44,
#  'fire': 45,
#  "i'm": 46,
#  'when': 47,
#  'if': 48,
#  'we': 49,
#  'get': 50,
#  'now': 51,
#  'new': 52,
#  'via': 53,
#  'more': 54,
#  '2': 55,
#  'about': 56,
#  'or': 57,
#  'news': 58,
#  'people': 59,
#  'what': 60,
#  'they': 61,
#  'one': 62,
#  'he': 63,
#  'how': 64,
#  'been': 65,
#  'over': 66,
#  'who': 67,
#  "it's": 68,
#  'into': 69,
#  "don't": 70,
#  'do': 71,
#  'video': 72,
#  "'": 73,
#  'can': 74,
#  'emergency': 75,
#  'disaster': 76,
#  'there': 77,
#  'police': 78,
#  'than': 79,
#  '3': 80,
#  'her': 81,
#  'u': 82,
#  'would': 83,
#  'still': 84,
#  'his': 85,
#  'some': 86,
#  'were': 87,
#  'body': 88,
#  'us': 89,
#  'burning': 90,
#  'back': 91,
#  'crash': 92,
#  'storm': 93,
#  'day': 94,
#  'time': 95,
#  'california': 96,
#  'them': 97,
#  '1': 98,
#  'off': 99,
#  'got': 100,
#  'know': 101,
#  'why': 102,
#  'suicide': 103,
#  'man': 104,
#  'rt': 105,
#  'had': 106,
#  's': 107,
#  'buildings': 108,
#  'first': 109,
#  'see': 110,
#  'going': 111,
#  'world': 112,
#  'bomb': 113,
#  'two': 114,
#  'fires': 115,
#  'nuclear': 116,
#  'love': 117,
#  'killed': 118,
#  'our': 119,
#  'year': 120,
#  'youtube': 121,
#  'dead': 122,
#  'attack': 123,
#  'their': 124,
#  'gt': 125,
#  'go': 126,
#  '4': 127,
#  'train': 128,
#  'full': 129,
#  'car': 130,
#  'life': 131,
#  '5': 132,
#  'war': 133,
#  'old': 134,
#  'hiroshima': 135,
#  'being': 136,
#  'today': 137,
#  'may': 138,
#  'accident': 139,
#  'only': 140,
#  'down': 141,
#  'families': 142,
#  "can't": 143,
#  'good': 144,
#  'here': 145,
#  'think': 146,
#  '2015': 147,
#  'say': 148,
#  'watch': 149,
#  'last': 150,
#  'many': 151,
#  'way': 152,
#  'home': 153,
#  'could': 154,
#  'did': 155,
#  'its': 156,
#  'years': 157,
#  'want': 158,
#  'then': 159,
#  'too': 160,
#  'w': 161,
#  'make': 162,
#  'collapse': 163,
#  'work': 164,
#  'because': 165,
#  'best': 166,
#  'look': 167,
#  'even': 168,
#  'mass': 169,
#  'help': 170,
#  'please': 171,
#  'another': 172,
#  'need': 173,
#  'take': 174,
#  'am': 175,
#  'really': 176,
#  'army': 177,
#  'mh370': 178,
#  'death': 179,
#  'wildfire': 180,
#  'lol': 181,
#  'bombing': 182,
#  'black': 183,
#  'him': 184,
#  'right': 185,
#  'should': 186,
#  'school': 187,
#  'those': 188,
#  'forest': 189,
#  "you're": 190,
#  '\x89û': 191,
#  'fatal': 192,
#  'hot': 193,
#  '8': 194,
#  'pm': 195,
#  'much': 196,
#  '11': 197,
#  'northern': 198,
#  'obama': 199,
#  'live': 200,
#  'never': 201,
#  'let': 202,
#  'city': 203,
#  '9': 204,
#  'she': 205,
#  'bomber': 206,
#  'great': 207,
#  'wreck': 208,
#  'latest': 209,
#  'homes': 210,
#  '6': 211,
#  'any': 212,
#  'every': 213,
#  'read': 214,
#  'god': 215,
#  'atomic': 216,
#  'typhoon': 217,
#  'flood': 218,
#  'said': 219,
#  'where': 220,
#  'flames': 221,
#  'fear': 222,
#  'shit': 223,
#  'im': 224,
#  'ever': 225,
#  'under': 226,
#  'injured': 227,
#  'floods': 228,
#  'near': 229,
#  'top': 230,
#  'getting': 231,
#  'damage': 232,
#  'come': 233,
#  'feel': 234,
#  'japan': 235,
#  'while': 236,
#  'most': 237,
#  'hit': 238,
#  "that's": 239,
#  'since': 240,
#  'cross': 241,
#  'oil': 242,
#  'before': 243,
#  '15': 244,
#  'everyone': 245,
#  'found': 246,
#  'hope': 247,
#  'military': 248,
#  'content': 249,
#  'coming': 250,
#  'stop': 251,
#  'during': 252,
#  '10': 253,
#  'weather': 254,
#  'ass': 255,
#  'evacuation': 256,
#  'night': 257,
#  'these': 258,
#  'next': 259,
#  'truck': 260,
#  'debris': 261,
#  'wild': 262,
#  'earthquake': 263,
#  'flooding': 264,
#  'state': 265,
#  'times': 266,
#  'which': 267,
#  'without': 268,
#  'plan': 269,
#  'malaysia': 270,
#  'smoke': 271,
#  'set': 272,
#  '08': 273,
#  'well': 274,
#  'movie': 275,
#  'lightning': 276,
#  'thunderstorm': 277,
#  'area': 278,
#  'heat': 279,
#  'check': 280,
#  'face': 281,
#  'through': 282,
#  'm': 283,
#  'water': 284,
#  'severe': 285,
#  'always': 286,
#  'fucking': 287,
#  'explosion': 288,
#  'little': 289,
#  'looks': 290,
#  'run': 291,
#  'made': 292,
#  'wounded': 293,
#  'sinking': 294,
#  'rain': 295,
#  'cause': 296,
#  'services': 297,
#  'high': 298,
#  'bad': 299,
#  'warning': 300,
#  '7': 301,
#  'says': 302,
#  'natural': 303,
#  'thunder': 304,
#  'until': 305,
#  'also': 306,
#  'bloody': 307,
#  'family': 308,
#  '70': 309,
#  'change': 310,
#  'liked': 311,
#  'hail': 312,
#  'fall': 313,
#  'hurricane': 314,
#  'spill': 315,
#  'injuries': 316,
#  'devastated': 317,
#  'loud': 318,
#  'reddit': 319,
#  'photo': 320,
#  'gonna': 321,
#  'head': 322,
#  'injury': 323,
#  'free': 324,
#  'house': 325,
#  'red': 326,
#  'again': 327,
#  'weapon': 328,
#  'weapons': 329,
#  'evacuate': 330,
#  'refugees': 331,
#  'summer': 332,
#  'end': 333,
#  'screaming': 334,
#  'p': 335,
#  'air': 336,
#  'blood': 337,
#  'missing': 338,
#  'wind': 339,
#  'bags': 340,
#  'trapped': 341,
#  'collided': 342,
#  'rescue': 343,
#  'fatalities': 344,
#  'murder': 345,
#  'destroy': 346,
#  'whole': 347,
#  'girl': 348,
#  'big': 349,
#  'released': 350,
#  'attacked': 351,
#  'explode': 352,
#  'derailment': 353,
#  'failure': 354,
#  'collision': 355,
#  'panic': 356,
#  'sinkhole': 357,
#  "i've": 358,
#  'breaking': 359,
#  'around': 360,
#  '40': 361,
#  'someone': 362,
#  'ambulance': 363,
#  "he's": 364,
#  'destruction': 365,
#  'boy': 366,
#  'destroyed': 367,
#  'real': 368,
#  'terrorism': 369,
#  'post': 370,
#  'saudi': 371,
#  'bag': 372,
#  'bridge': 373,
#  'hazard': 374,
#  'harm': 375,
#  'wreckage': 376,
#  'outbreak': 377,
#  'update': 378,
#  'week': 379,
#  '\x89ûò': 380,
#  'burned': 381,
#  'does': 382,
#  'road': 383,
#  'game': 384,
#  'trauma': 385,
#  'survivors': 386,
#  'survive': 387,
#  '05': 388,
#  'charged': 389,
#  'terrorist': 390,
#  'battle': 391,
#  'keep': 392,
#  'report': 393,
#  'drought': 394,
#  'deaths': 395,
#  'migrants': 396,
#  'twister': 397,
#  'wrecked': 398,
#  'county': 399,
#  'd': 400,
#  'tonight': 401,
#  'n': 402,
#  'o': 403,
#  'call': 404,
#  'ok': 405,
#  'self': 406,
#  'away': 407,
#  'against': 408,
#  'white': 409,
#  'fuck': 410,
#  'bombed': 411,
#  'rescuers': 412,
#  'displaced': 413,
#  'boat': 414,
#  'ruin': 415,
#  'service': 416,
#  'rescued': 417,
#  'crush': 418,
#  'survived': 419,
#  'dust': 420,
#  'windstorm': 421,
#  "there's": 422,
#  'bus': 423,
#  '30': 424,
#  'crashed': 425,
#  'august': 426,
#  '0': 427,
#  'things': 428,
#  'story': 429,
#  'twitter': 430,
#  'put': 431,
#  'show': 432,
#  'lives': 433,
#  'riot': 434,
#  'hazardous': 435,
#  'curfew': 436,
#  'danger': 437,
#  'massacre': 438,
#  'structural': 439,
#  'whirlwind': 440,
#  'other': 441,
#  'least': 442,
#  'came': 443,
#  'island': 444,
#  'suspect': 445,
#  'phone': 446,
#  'long': 447,
#  'saw': 448,
#  'violent': 449,
#  'hostage': 450,
#  'wanna': 451,
#  'tragedy': 452,
#  'half': 453,
#  'traumatised': 454,
#  'catastrophe': 455,
#  'chemical': 456,
#  'collapsed': 457,
#  'landslide': 458,
#  'deluge': 459,
#  'derailed': 460,
#  'devastation': 461,
#  'screamed': 462,
#  'famine': 463,
#  'investigators': 464,
#  'hostages': 465,
#  'quarantined': 466,
#  'sandstorm': 467,
#  'sunk': 468,
#  'tornado': 469,
#  'wave': 470,
#  'better': 471,
#  'horrible': 472,
#  'past': 473,
#  'heard': 474,
#  'thing': 475,
#  'airplane': 476,
#  'kills': 477,
#  'national': 478,
#  'apocalypse': 479,
#  'heart': 480,
#  'part': 481,
#  'woman': 482,
#  'power': 483,
#  'women': 484,
#  'oh': 485,
#  'bleeding': 486,
#  'blown': 487,
#  'anniversary': 488,
#  'rioting': 489,
#  'casualties': 490,
#  'stock': 491,
#  'derail': 492,
#  'desolation': 493,
#  'drowning': 494,
#  'engulfed': 495,
#  'inundated': 496,
#  'bang': 497,
#  'quarantine': 498,
#  'screams': 499,
#  "i'll": 500,
#  'meltdown': 501,
#  'plane': 502,
#  'iran': 503,
#  'went': 504,
#  'save': 505,
#  'b': 506,
#  'group': 507,
#  'fedex': 508,
#  'light': 509,
#  'catastrophic': 510,
#  'cliff': 511,
#  'wounds': 512,
#  'hundreds': 513,
#  'electrocuted': 514,
#  'exploded': 515,
#  'fatality': 516,
#  'flattened': 517,
#  'lava': 518,
#  'st': 519,
#  'something': 520,
#  'use': 521,
#  'thank': 522,
#  "'the": 523,
#  'ebay': 524,
#  'lot': 525,
#  'must': 526,
#  'food': 527,
#  'zone': 528,
#  'soon': 529,
#  'armageddon': 530,
#  'mosque': 531,
#  'blew': 532,
#  'drown': 533,
#  'land': 534,
#  'bagging': 535,
#  '00': 536,
#  'caused': 537,
#  'affected': 538,
#  'trouble': 539,
#  'tsunami': 540,
#  'evacuated': 541,
#  'hellfire': 542,
#  'hijacker': 543,
#  'pandemonium': 544,
#  'panicking': 545,
#  'razed': 546,
#  'cool': 547,
#  'left': 548,
#  'very': 549,
#  'minute': 550,
#  'reunion': 551,
#  'sure': 552,
#  'river': 553,
#  'calgary': 554,
#  'bioterror': 555,
#  'blazing': 556,
#  'market': 557,
#  'send': 558,
#  'baby': 559,
#  "legionnaires'": 560,
#  'hijacking': 561,
#  'rainstorm': 562,
#  'due': 563,
#  'south': 564,
#  'care': 565,
#  'r': 566,
#  'traffic': 567,
#  'doing': 568,
#  'possible': 569,
#  'goes': 570,
#  'government': 571,
#  'thought': 572,
#  'kill': 573,
#  'tomorrow': 574,
#  'officials': 575,
#  'india': 576,
#  'longer': 577,
#  'security': 578,
#  'e': 579,
#  'song': 580,
#  'pkk': 581,
#  'casualty': 582,
#  'collide': 583,
#  'crushed': 584,
#  'isis': 585,
#  'demolish': 586,
#  'demolition': 587,
#  'detonation': 588,
#  'drowned': 589,
#  'volcano': 590,
#  'murderer': 591,
#  'obliterated': 592,
#  'detonated': 593,
#  'building': 594,
#  'three': 595,
#  'used': 596,
#  'kids': 597,
#  'issues': 598,
#  'same': 599,
#  'airport': 600,
#  'annihilated': 601,
#  'fan': 602,
#  'arson': 603,
#  'sound': 604,
#  'stay': 605,
#  'music': 606,
#  'beautiful': 607,
#  'c': 608,
#  'nothing': 609,
#  'shoulder': 610,
#  'responders': 611,
#  'officer': 612,
#  'cyclone': 613,
#  'blast': 614,
#  'demolished': 615,
#  'prebreak': 616,
#  'mudslide': 617,
#  'obliterate': 618,
#  'days': 619,
#  'thanks': 620,
#  'few': 621,
#  'already': 622,
#  'making': 623,
#  'done': 624,
#  'believe': 625,
#  'lt': 626,
#  'hours': 627,
#  'fight': 628,
#  'start': 629,
#  'yet': 630,
#  'media': 631,
#  'remember': 632,
#  '50': 633,
#  'ur': 634,
#  'detonate': 635,
#  'electrocute': 636,
#  'eyewitness': 637,
#  'obliteration': 638,
#  'siren': 639,
#  'upheaval': 640,
#  'died': 641,
#  'far': 642,
#  'ablaze': 643,
#  'inside': 644,
#  'leave': 645,
#  '16': 646,
#  'shooting': 647,
#  'actually': 648,
#  'men': 649,
#  'wake': 650,
#  'fun': 651,
#  'israeli': 652,
#  'person': 653,
#  'having': 654,
#  'bioterrorism': 655,
#  'blight': 656,
#  'policy': 657,
#  'such': 658,
#  'turkey': 659,
#  'mp': 660,
#  'legionnaires': 661,
#  'hijack': 662,
#  'sue': 663,
#  '16yr': 664,
#  'both': 665,
#  'site': 666,
#  'shot': 667,
#  'north': 668,
#  '06': 669,
#  'support': 670,
#  'die': 671,
#  'play': 672,
#  'sirens': 673,
#  'stand': 674,
#  'order': 675,
#  'peace': 676,
#  'trying': 677,
#  'lab': 678,
#  'health': 679,
#  'yes': 680,
#  'pic': 681,
#  're\x89û': 682,
#  'words': 683,
#  'nearby': 684,
#  'bush': 685,
#  'deluged': 686,
#  'declares': 687,
#  'seismic': 688,
#  'reactor': 689,
#  'wait': 690,
#  '\x89ûó': 691,
#  'nowplaying': 692,
#  'plans': 693,
#  'gets': 694,
#  'yourself': 695,
#  'brown': 696,
#  'ago': 697,
#  'horror': 698,
#  "i'd": 699,
#  'children': 700,
#  'anything': 701,
#  'guys': 702,
#  "doesn't": 703,
#  'abc': 704,
#  'line': 705,
#  'low': 706,
#  'find': 707,
#  '25': 708,
#  '01': 709,
#  'islam': 710,
#  'rubble': 711,
#  'swallowed': 712,
#  'stretcher': 713,
#  'place': 714,
#  'second': 715,
#  "what's": 716,
#  'outside': 717,
#  'tell': 718,
#  'job': 719,
#  'almost': 720,
#  'aircraft': 721,
#  'helicopter': 722,
#  'history': 723,
#  'bc': 724,
#  'data': 725,
#  'own': 726,
#  'business': 727,
#  'yeah': 728,
#  'deal': 729,
#  'photos': 730,
#  'watching': 731,
#  'bigger': 732,
#  'memories': 733,
#  'saipan': 734,
#  'snowstorm': 735,
#  "'conclusively": 736,
#  "confirmed'": 737,
#  'lost': 738,
#  'west': 739,
#  'happy': 740,
#  'center': 741,
#  "didn't": 742,
#  'book': 743,
#  'anyone': 744,
#  'reuters': 745,
#  'hey': 746,
#  'bar': 747,
#  'hell': 748,
#  'maybe': 749,
#  'pick': 750,
#  'tv': 751,
#  'control': 752,
#  'american': 753,
#  'makes': 754,
#  'literally': 755,
#  'avalanche': 756,
#  'transport': 757,
#  'searching': 758,
#  'blizzard': 759,
#  'rise': 760,
#  'x': 761,
#  'hear': 762,
#  'waves': 763,
#  'bodies': 764,
#  'desolate': 765,
#  'projected': 766,
#  'hat': 767,
#  'bestnaijamade': 768,
#  'street': 769,
#  'side': 770,
#  'rd': 771,
#  'finally': 772,
#  'property': 773,
#  'might': 774,
#  'eyes': 775,
#  'pakistan': 776,
#  'amid': 777,
#  'damn': 778,
#  'team': 779,
#  'feeling': 780,
#  'listen': 781,
#  'space': 782,
#  'hollywood': 783,
#  'pretty': 784,
#  'move': 785,
#  'online': 786,
#  'though': 787,
#  'morning': 788,
#  'money': 789,
#  'probably': 790,
#  'aug': 791,
#  'saved': 792,
#  'crews': 793,
#  'trains': 794,
#  'soudelor': 795,
#  'signs': 796,
#  'effect': 797,
#  'manslaughter': 798,
#  'la': 799,
#  '20': 800,
#  'fast': 801,
#  'arsonist': 802,
#  'mom': 803,
#  'once': 804,
#  'wrong': 805,
#  'feared': 806,
#  '17': 807,
#  'hate': 808,
#  'everything': 809,
#  'country': 810,
#  'seen': 811,
#  'case': 812,
#  'annihilation': 813,
#  "we're": 814,
#  'major': 815,
#  'child': 816,
#  'crisis': 817,
#  'leather': 818,
#  'caught': 819,
#  'town': 820,
#  'blaze': 821,
#  'okay': 822,
#  'youth': 823,
#  'nearly': 824,
#  'spot': 825,
#  'myself': 826,
#  'confirmed': 827,
#  'image': 828,
#  'sensor': 829,
#  'trench': 830,
#  'hailstorm': 831,
#  'refugio': 832,
#  'costlier': 833,
#  'miners': 834,
#  '13': 835,
#  'flash': 836,
#  'flag': 837,
#  'cars': 838,
#  'lord': 839,
#  'vehicle': 840,
#  'aftershock': 841,
#  'daily': 842,
#  'guy': 843,
#  'jobs': 844,
#  "they're": 845,
#  'ship': 846,
#  '12': 847,
#  'crazy': 848,
#  'sorry': 849,
#  'ball': 850,
#  'usa': 851,
#  'called': 852,
#  'name': 853,
#  'class': 854,
#  'texas': 855,
#  'worst': 856,
#  'needs': 857,
#  'fukushima': 858,
#  'wow': 859,
#  'russian': 860,
#  'giant': 861,
#  'angry': 862,
#  'course': 863,
#  'banned': 864,
#  'knock': 865,
#  'picking': 866,
#  'mayhem': 867,
#  'reason': 868,
#  'closed': 869,
#  'heavy': 870,
#  'across': 871,
#  'haha': 872,
#  'others': 873,
#  'huge': 874,
#  'talk': 875,
#  'win': 876,
#  'official': 877,
#  "she's": 878,
#  'omg': 879,
#  'sign': 880,
#  'poor': 881,
#  'action': 882,
#  'toddler': 883,
#  'united': 884,
#  "isn't": 885,
#  'east': 886,
#  'gun': 887,
#  'anthrax': 888,
#  'running': 889,
#  'computers': 890,
#  'dont': 891,
#  'follow': 892,
#  'entire': 893,
#  'link': 894,
#  'meek': 895,
#  '60': 896,
#  'gbbo': 897,
#  'houses': 898,
#  'chance': 899,
#  'friends': 900,
#  'bbc': 901,
#  'uk': 902,
#  'ignition': 903,
#  'offensive': 904,
#  'try': 905,
#  'wanted': 906,
#  'chicago': 907,
#  'alone': 908,
#  'hard': 909,
#  'yours': 910,
#  "'i": 911,
#  'america': 912,
#  'happened': 913,
#  'radio': 914,
#  'totally': 915,
#  '100': 916,
#  'learn': 917,
#  'truth': 918,
#  'beach': 919,
#  'ca': 920,
#  'reports': 921,
#  'christian': 922,
#  'muslims': 923,
#  'temple': 924,
#  'mount': 925,
#  'view': 926,
#  'eye': 927,
#  'taken': 928,
#  'playing': 929,
#  'mishaps': 930,
#  'public': 931,
#  'mad': 932,
#  "let's": 933,
#  'cake': 934,
#  'level': 935,
#  'ladies': 936,
#  'appears': 937,
#  'centre': 938,
#  'village': 939,
#  'alarm': 940,
#  'takes': 941,
#  'china': 942,
#  'issued': 943,
#  'emmerdale': 944,
#  "'we're": 945,
#  'become': 946,
#  'cnn': 947,
#  'declaration': 948,
#  'disea': 949,
#  '18': 950,
#  'myanmar': 951,
#  'front': 952,
#  'climate': 953,
#  'else': 954,
#  '24': 955,
#  'drive': 956,
#  'global': 957,
#  'experts': 958,
#  'france': 959,
#  '\x89ûï': 960,
#  'dog': 961,
#  'ready': 962,
#  'vs': 963,
#  'film': 964,
#  'till': 965,
#  'friend': 966,
#  'blue': 967,
#  'green': 968,
#  'driving': 969,
#  'favorite': 970,
#  'star': 971,
#  'germs': 972,
#  'looking': 973,
#  'pain': 974,
#  "ain't": 975,
#  'large': 976,
#  'womens': 977,
#  'drake': 978,
#  'marks': 979,
#  'downtown': 980,
#  'insurance': 981,
#  'mph': 982,
#  'instead': 983,
#  'coaches': 984,
#  'sea': 985,
#  'flight': 986,
#  'quiz': 987,
#  "reddit's": 988,
#  "water'": 989,
#  'virgin': 990,
#  'chile': 991,
#  'bring': 992,
#  'thousands': 993,
#  'reported': 994,
#  'dies': 995,
#  'turned': 996,
#  'moment': 997,
#  'behind': 998,
#  'four': 999,
#  'early': 1000,
#  ...}

# %%
X_train = token.texts_to_sequences(X_train)
X_test = token.texts_to_sequences(X_test)

# %%
max_len = max([len(i) for i in X_train])

# %%
X_train = pad_sequences(X_train, maxlen=max_len, padding='post')
X_test = pad_sequences(X_test, maxlen=max_len, padding='post')

# %%
X_train.shape
# Out:
# (7613, 33)

# %%
X_test.shape
# Out:
# (3263, 33)

# %%
y_train.shape
# Out:
# (7613,)

# %%
y_train
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7608    1
# 7609    1
# 7610    1
# 7611    1
# 7612    1
# Name: target, Length: 7613, dtype: int64

# %%
from keras.utils import to_categorical

# %%
y_train = to_categorical(y_train, num_classes=2)

# %%
y_train.shape
# Out:
# (7613, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, random_state=42)

# %%
from keras.optimizers import Adam

# %%
word_count = len(token.word_index) + 1

# %%
y_train.shape
# Out:
# (6471, 2)

# %%
y_val.shape
# Out:
# (1142, 2)

# %%
model = Sequential()

model.add(Embedding(input_dim=word_count, output_dim=20, input_length=max_len))
model.add(LSTM(input_dim=20,units=20, activation='relu'))

model.add(Dense(units=8, activation='relu'))
model.add(Dense(units=2, activation='softmax'))
# Out:
# C:\Users\User\OneDrive\Desktop\ml-2001\venv\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# C:\Users\User\OneDrive\Desktop\ml-2001\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20)
# Out:
# Epoch 1/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.5684 - loss: 0.6897 - val_accuracy: 0.5701 - val_loss: 0.6870
# Epoch 2/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.5704 - loss: 0.6856 - val_accuracy: 0.5701 - val_loss: 0.6846
# Epoch 3/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.5704 - loss: 0.6841 - val_accuracy: 0.5701 - val_loss: 0.6837
# Epoch 4/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.5712 - loss: 0.7497 - val_accuracy: 0.5701 - val_loss: 0.6833
# Epoch 5/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.5704 - loss: 0.6830 - val_accuracy: 0.5701 - val_loss: 0.6830
# Epoch 6/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.5705 - loss: 0.6824 - val_accuracy: 0.5701 - val_loss: 0.6826
# Epoch 7/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.5721 - loss: 0.6810 - val_accuracy: 0.5727 - val_loss: 0.6805
# Epoch 8/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.6251 - loss: 0.6579 - val_accuracy: 0.6646 - val_loss: 0.6547
# Epoch 9/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.8073 - loss: 0.5436 - val_accuracy: 0.7364 - val_loss: 0.5702
# Epoch 10/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.8799 - loss: 0.4118 - val_accuracy: 0.7715 - val_loss: 0.5621
# Epoch 11/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.8962 - loss: 0.3602 - val_accuracy: 0.7793 - val_loss: 0.5372
# Epoch 12/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9108 - loss: 0.3088 - val_accuracy: 0.7732 - val_loss: 0.5593
# Epoch 13/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.8855 - loss: 0.4050 - val_accuracy: 0.7478 - val_loss: 0.5286
# Epoch 14/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9196 - loss: 0.2821 - val_accuracy: 0.7881 - val_loss: 0.5241
# Epoch 15/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9351 - loss: 0.2380 - val_accuracy: 0.7846 - val_loss: 0.5817
# Epoch 16/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9373 - loss: 0.2232 - val_accuracy: 0.7767 - val_loss: 0.6084
# Epoch 17/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9408 - loss: 0.2134 - val_accuracy: 0.7828 - val_loss: 0.6346
# Epoch 18/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9428 - loss: 0.2045 - val_accuracy: 0.7820 - val_loss: 0.6734
# Epoch 19/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9436 - loss: 0.1992 - val_accuracy: 0.7785 - val_loss: 0.7817
# Epoch 20/20
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9437 - loss: 0.1962 - val_accuracy: 0.7802 - val_loss: 0.7398

# %%
y_train
# Out:
# array([[0., 1.],
#        [0., 1.],
#        [1., 0.],
#        ...,
#        [1., 0.],
#        [0., 1.],
#        [0., 1.]], shape=(6471, 2))

# %%
X_test.shape
# Out:
# (3263, 33)

# %%
y_train.shape
# Out:
# (6471, 2)

# %%
y_val.shape
# Out:
# (1142, 2)

# %%
X_val.shape
# Out:
# (1142, 33)

# %%
y_pred = model.predict(X_test)
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
y_pred
# Out:
# array([[9.78060067e-01, 2.19399650e-02],
#        [9.22700747e-06, 9.99990821e-01],
#        [1.03846794e-07, 9.99999881e-01],
#        ...,
#        [1.32626765e-13, 1.00000000e+00],
#        [9.78060067e-01, 2.19399650e-02],
#        [1.37969224e-07, 9.99999881e-01]], shape=(3263, 2), dtype=float32)

# %%
y_pred = [np.argmax(i) for i in y_pred]

# %%
df_sub.to_csv('sub.csv', index=False, index_label=False)

# %%
len(y_pred)
# Out:
# 3263
